# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country=citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = cities[1]
units = "imperial"
cloudiness=[]
date=[]
humidity=[]
lat=[]
lng=[]
temp=[]
wind_speed=[]

counter=1

for city in cities:
     try:
        query_url = f"{url}appid={api_key}&q={city}&units={units}"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        cloudiness.append(weather_json["clouds"]["all"])
        humidity.append(weather_json["main"]["humidity"])
        lat.append(weather_json["coord"]["lat"])
        lng.append(weather_json["coord"]["lon"])
        temp.append(weather_json["main"]["temp_max"])
        wind_speed.append(weather_json["wind"]["speed"])
     except KeyError:
        print("Oops, that key doesn't exist.")
        print(f'city number {counter}: city name {city}')
        counter+=1
# Out:
# Oops, that key doesn't exist.
# city number 1: city name marcona
# Oops, that key doesn't exist.
# city number 2: city name vaitupu
# Oops, that key doesn't exist.
# city number 3: city name formoso do araguaia
# Oops, that key doesn't exist.
# city number 4: city name phan rang
# Oops, that key doesn't exist.
# city number 5: city name barentsburg
# Oops, that key doesn't exist.
# city number 6: city name warqla
# Oops, that key doesn't exist.
# city number 7: city name taolanaro
# Oops, that key doesn't exist.
# city number 8: city name mutsamudu
# Oops, that key doesn't exist.
# city number 9: city name podbelsk
# Oops, that key doesn't exist.
# city number 10: city name mys shmidta
# Oops, that key doesn't exist.
# city number 11: city name tsihombe
# Oops, that key doesn't exist.
# city number 12: city name karaul
# Oops, that key doesn't exist.
# city number 13: city name yanan
# Oops, that key doesn't exist.
# city number 14: city name bargal
# Oops, that key doesn't exist.
# city number 15: city name ust-kamchatsk
# Oops, that key doesn't exist.
# city number 16: city name kamenskoye
# Oops, that key doesn't exist.
# city number 17: city name samusu
# Oops, that key doesn't exist.
# city number 18: city name saleaula
# Oops, that key doesn't exist.
# city number 19: city name illoqqortoormiut
# Oops, that key doesn't exist.
# city number 20: city name bengkulu
# Oops, that key doesn't exist.
# city number 21: city name sembe
# Oops, that key doesn't exist.
# city number 22: city name burica
# Oops, that key doesn't exist.
# city number 23: city name belushya guba
# Oops, that key doesn't exist.
# city number 24: city name crab hill
# Oops, that key doesn't exist.
# city number 25: city name witrivier
# Oops, that key doesn't exist.
# city number 26: city name sakakah
# Oops, that key doesn't exist.
# city number 27: city name asayita
# Oops, that key doesn't exist.
# city number 28: city name asfi
# Oops, that key doesn't exist.
# city number 29: city name falealupo
# Oops, that key doesn't exist.
# city number 30: city name nizhneyansk
# Oops, that key doesn't exist.
# city number 31: city name bababe
# Oops, that key doesn't exist.
# city number 32: city name buariki
# Oops, that key doesn't exist.
# city number 33: city name paradwip
# Oops, that key doesn't exist.
# city number 34: city name pietersburg
# Oops, that key doesn't exist.
# city number 35: city name olafsvik
# Oops, that key doesn't exist.
# city number 36: city name lolua
# Oops, that key doesn't exist.
# city number 37: city name fevralsk
# Oops, that key doesn't exist.
# city number 38: city name sentyabrskiy
# Oops, that key doesn't exist.
# city number 39: city name palabuhanratu
# Oops, that key doesn't exist.
# city number 40: city name murud
# Oops, that key doesn't exist.
# city number 41: city name tumannyy
# Oops, that key doesn't exist.
# city number 42: city name ksenyevka
# Oops, that key doesn't exist.
# city number 43: city name gangotri
# Oops, that key doesn't exist.
# city number 44: city name attawapiskat
# Oops, that key doesn't exist.
# city number 45: city name bur gabo
# Oops, that key doesn't exist.
# city number 46: city name amderma
# Oops, that key doesn't exist.
# city number 47: city name artyk
# Oops, that key doesn't exist.
# city number 48: city name sumbawa
# Oops, that key doesn't exist.
# city number 49: city name vreed en hoop
# Oops, that key doesn't exist.
# city number 50: city name play cu
# Oops, that key doesn't exist.
# city number 51: city name grand river south east
# Oops, that key doesn't exist.
# city number 52: city name haibowan
# Oops, that key doesn't exist.
# city number 53: city name bolungarvik
# Oops, that key doesn't exist.
# city number 54: city name sofiysk
# Oops, that key doesn't exist.
# city number 55: city name umzimvubu
# Oops, that key doesn't exist.
# city number 56: city name bairiki
# Oops, that key doesn't exist.
# city number 57: city name sao raimundo nonato
# Oops, that key doesn't exist.
# city number 58: city name kegayli
# Oops, that key doesn't exist.
# city number 59: city name qui nhon
# Oops, that key doesn't exist.
# city number 60: city name porto santo
# Oops, that key doesn't exist.
# city number 61: city name andarab

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data=pd.DataFrame({"City":cities[0:len(cloudiness)], "Cloudiness":cloudiness,"Country":country,"Humidity":humidity,"Lat":lat,"Lng":lng, "Max Temp":temp,"Wind Speed":wind_speed})
data.head()
# Out:
#            City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0       qaanaaq          12      pf        75  77.48  -69.36     -3.88
# 1        atuona           0      pf       100  -9.80 -139.03     82.07
# 2   yellowknife          75      pf        79  62.45 -114.38     26.01
# 3  punta arenas          40      pf        58 -53.16  -70.91     53.60
# 4           bud          75      pf        65  62.91    6.91     44.60
#
#    Wind Speed
# 0        8.75
# 1       12.66
# 2        4.70
# 3       44.96
# 4       25.28

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data["Lat"],data["Max Temp"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Max Temparature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("LatvsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data["Lat"],data["Humidity"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig("LatvsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data["Lat"],data["Cloudiness"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data["Lat"],data["Wind Speed"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("LatvsWind.png")
