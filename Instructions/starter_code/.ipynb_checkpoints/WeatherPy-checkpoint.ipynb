# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries=[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country=citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_new=[]
country_new=[]
cloudiness=[]
date=[]
humidity=[]
lat=[]
lng=[]
temp=[]
wind_speed=[]

counter=1

for city in cities:
     try:
        query_url = f"{url}appid={api_key}&q={city}&units={units}"
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        city_new.append(city)
        country_new.append(countries[cities.index(city)])
        cloudiness.append(weather_json["clouds"]["all"])
        humidity.append(weather_json["main"]["humidity"])
        lat.append(weather_json["coord"]["lat"])
        lng.append(weather_json["coord"]["lon"])
        temp.append(weather_json["main"]["temp_max"])
        wind_speed.append(weather_json["wind"]["speed"])
        print(f'city number {counter}: city name {city}')
        counter+=1
     except KeyError:
        print("Oops, that key doesn't exist.")
        del city_new[-1]
        del country_new[-1]
# Out:
# city number 1: city name mataura
# city number 2: city name bethel
# city number 3: city name port blair
# city number 4: city name sao joao da barra
# city number 5: city name cape town
# Oops, that key doesn't exist.
# city number 6: city name qaanaaq
# city number 7: city name caravelas
# city number 8: city name cherskiy
# city number 9: city name ushuaia
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# city number 10: city name tommot
# city number 11: city name karratha
# city number 12: city name itarema
# city number 13: city name airai
# city number 14: city name saskylakh
# city number 15: city name saint-philippe
# city number 16: city name dikson
# city number 17: city name la rioja
# city number 18: city name jamestown
# city number 19: city name tuktoyaktuk
# city number 20: city name avarua
# city number 21: city name vaini
# city number 22: city name carnarvon
# city number 23: city name east london
# city number 24: city name preobrazheniye
# city number 25: city name guerrero negro
# city number 26: city name pudozh
# Oops, that key doesn't exist.
# city number 27: city name busselton
# city number 28: city name tual
# city number 29: city name albany
# city number 30: city name riyadh
# city number 31: city name teofilo otoni
# city number 32: city name kapaa
# city number 33: city name sfantu gheorghe
# city number 34: city name caucasia
# Oops, that key doesn't exist.
# city number 35: city name padang
# city number 36: city name cervo
# city number 37: city name tasiilaq
# city number 38: city name montepuez
# city number 39: city name elizabeth city
# city number 40: city name berlevag
# city number 41: city name marawi
# city number 42: city name laguna
# city number 43: city name souillac
# city number 44: city name tiksi
# city number 45: city name chara
# city number 46: city name hemsedal
# city number 47: city name ponta do sol
# city number 48: city name hithadhoo
# city number 49: city name kruisfontein
# city number 50: city name muhos
# city number 51: city name kavaratti
# city number 52: city name new norfolk
# city number 53: city name barrow
# city number 54: city name port-cartier
# city number 55: city name lata
# city number 56: city name cockburn town
# city number 57: city name upernavik
# city number 58: city name suez
# city number 59: city name praia da vitoria
# city number 60: city name atuona
# city number 61: city name victoria
# city number 62: city name elk grove
# city number 63: city name faanui
# city number 64: city name bilma
# city number 65: city name punta arenas
# city number 66: city name lebu
# city number 67: city name presidente olegario
# city number 68: city name bluff
# city number 69: city name haicheng
# city number 70: city name avera
# Oops, that key doesn't exist.
# city number 71: city name hermanus
# city number 72: city name rikitea
# city number 73: city name bredasdorp
# city number 74: city name liwale
# city number 75: city name jati
# city number 76: city name georgetown
# city number 77: city name hofn
# city number 78: city name hobart
# Oops, that key doesn't exist.
# city number 79: city name kasongo-lunda
# city number 80: city name ostrovnoy
# city number 81: city name santa ana
# city number 82: city name leningradskiy
# Oops, that key doesn't exist.
# city number 83: city name miramar
# city number 84: city name luderitz
# city number 85: city name mutsu
# city number 86: city name pangnirtung
# city number 87: city name poum
# city number 88: city name pontal do parana
# city number 89: city name bara
# Oops, that key doesn't exist.
# city number 90: city name yacuiba
# city number 91: city name chokurdakh
# city number 92: city name ambon
# city number 93: city name mahebourg
# Oops, that key doesn't exist.
# city number 94: city name castro
# city number 95: city name puerto escondido
# city number 96: city name hualmay
# city number 97: city name mahanoro
# city number 98: city name igarka
# city number 99: city name mutoko
# city number 100: city name trinidad
# city number 101: city name yellowknife
# city number 102: city name belmonte
# city number 103: city name upata
# city number 104: city name nyurba
# city number 105: city name khatanga
# city number 106: city name bisira
# city number 107: city name butaritari
# Oops, that key doesn't exist.
# city number 108: city name qeshm
# city number 109: city name finschhafen
# city number 110: city name birjand
# Oops, that key doesn't exist.
# city number 111: city name santa isabel do rio negro
# city number 112: city name severo-kurilsk
# Oops, that key doesn't exist.
# city number 113: city name kitami
# city number 114: city name wajir
# city number 115: city name longyearbyen
# city number 116: city name almonte
# city number 117: city name timoteo
# city number 118: city name kamiiso
# city number 119: city name katsuura
# city number 120: city name broome
# city number 121: city name perrysburg
# city number 122: city name henties bay
# city number 123: city name raton
# city number 124: city name zyryanka
# city number 125: city name hay river
# city number 126: city name oranjemund
# city number 127: city name teseney
# city number 128: city name kavieng
# city number 129: city name pevek
# city number 130: city name norman wells
# city number 131: city name maragogi
# city number 132: city name touros
# city number 133: city name pringsewu
# city number 134: city name richards bay
# city number 135: city name standish
# city number 136: city name port hawkesbury
# city number 137: city name cabo san lucas
# city number 138: city name sitka
# city number 139: city name koumac
# city number 140: city name leh
# city number 141: city name sayansk
# city number 142: city name codrington
# city number 143: city name lhokseumawe
# Oops, that key doesn't exist.
# city number 144: city name banda aceh
# city number 145: city name amga
# city number 146: city name verkhnetulomskiy
# city number 147: city name puerto ayora
# city number 148: city name san cristobal
# Oops, that key doesn't exist.
# city number 149: city name san patricio
# city number 150: city name hovd
# city number 151: city name hilo
# city number 152: city name edd
# city number 153: city name champa
# city number 154: city name motril
# Oops, that key doesn't exist.
# city number 155: city name asyut
# city number 156: city name sibolga
# city number 157: city name lithakia
# city number 158: city name cascais
# city number 159: city name ust-kut
# city number 160: city name teguldet
# city number 161: city name plouzane
# city number 162: city name vardo
# city number 163: city name chernyshevskiy
# city number 164: city name bheramara
# city number 165: city name zhangye
# city number 166: city name taltal
# city number 167: city name buraydah
# city number 168: city name mar del plata
# city number 169: city name le passage
# city number 170: city name nha trang
# city number 171: city name samarai
# city number 172: city name hokitika
# Oops, that key doesn't exist.
# city number 173: city name acapulco
# city number 174: city name at-bashi
# city number 175: city name victor harbor
# city number 176: city name sao filipe
# city number 177: city name hutang
# city number 178: city name yenagoa
# city number 179: city name lompoc
# city number 180: city name sungurlare
# city number 181: city name plettenberg bay
# city number 182: city name nouadhibou
# city number 183: city name birobidzhan
# city number 184: city name naryan-mar
# city number 185: city name kaliua
# city number 186: city name coquimbo
# city number 187: city name senekal
# Oops, that key doesn't exist.
# city number 188: city name baghdad
# city number 189: city name general roca
# city number 190: city name nome
# city number 191: city name la maddalena
# city number 192: city name sabang
# city number 193: city name lagoa
# city number 194: city name taoudenni
# city number 195: city name ambilobe
# city number 196: city name ancud
# city number 197: city name saint george
# city number 198: city name hasaki
# city number 199: city name morant bay
# city number 200: city name palotina
# city number 201: city name gelendzhik
# city number 202: city name marzuq
# city number 203: city name biscarrosse
# city number 204: city name leninskoye
# city number 205: city name ribeira grande
# city number 206: city name aklavik
# city number 207: city name dzaoudzi
# city number 208: city name nikolskoye
# city number 209: city name port macquarie
# city number 210: city name katangli
# city number 211: city name yar-sale
# city number 212: city name port hedland
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# city number 213: city name ulety
# city number 214: city name thompson
# city number 215: city name fort nelson
# city number 216: city name burnie
# city number 217: city name port alfred
# city number 218: city name slavgorod
# city number 219: city name rocha
# Oops, that key doesn't exist.
# city number 220: city name morondava
# city number 221: city name cidreira
# city number 222: city name bambous virieux
# city number 223: city name pilar
# city number 224: city name tessalit
# Oops, that key doesn't exist.
# city number 225: city name sinnamary
# city number 226: city name quatre cocos
# Oops, that key doesn't exist.
# city number 227: city name muros
# Oops, that key doesn't exist.
# city number 228: city name provideniya
# city number 229: city name solnechnyy
# city number 230: city name zuenoula
# city number 231: city name flinders
# city number 232: city name bathsheba
# Oops, that key doesn't exist.
# city number 233: city name orcopampa
# city number 234: city name geraldton
# city number 235: city name kijang
# city number 236: city name porto walter
# city number 237: city name cikupa
# Oops, that key doesn't exist.
# city number 238: city name svetlaya
# city number 239: city name huarmey
# city number 240: city name kodiak
# city number 241: city name camopi
# city number 242: city name russell
# city number 243: city name nachingwea
# city number 244: city name kaitangata
# city number 245: city name hounde
# city number 246: city name boddam
# city number 247: city name fairbanks
# city number 248: city name orange walk
# city number 249: city name namibe
# city number 250: city name brattvag
# city number 251: city name bandarbeyla
# city number 252: city name olot
# city number 253: city name saint-augustin
# city number 254: city name mbini
# city number 255: city name iqaluit
# city number 256: city name panama city
# city number 257: city name west bay
# city number 258: city name mildura
# city number 259: city name honningsvag
# city number 260: city name maraa
# city number 261: city name ayagoz
# city number 262: city name nouakchott
# city number 263: city name narsaq
# city number 264: city name sorland
# city number 265: city name langelsheim
# Oops, that key doesn't exist.
# city number 266: city name mwingi
# city number 267: city name aitape
# city number 268: city name grand gaube
# city number 269: city name karpathos
# city number 270: city name marquette
# Oops, that key doesn't exist.
# city number 271: city name portland
# city number 272: city name baker city
# city number 273: city name aiani
# city number 274: city name wiarton
# city number 275: city name guider
# city number 276: city name haines junction
# city number 277: city name coffs harbour
# city number 278: city name dingle
# city number 279: city name haimen
# city number 280: city name arraial do cabo
# city number 281: city name klaksvik
# city number 282: city name bindura
# city number 283: city name yeppoon
# city number 284: city name bahia blanca
# city number 285: city name monrovia
# city number 286: city name kuruman
# city number 287: city name smithers
# city number 288: city name port elizabeth
# city number 289: city name port hardy
# city number 290: city name kassala
# city number 291: city name mesyagutovo
# Oops, that key doesn't exist.
# city number 292: city name dwarka
# city number 293: city name saint anthony
# city number 294: city name esperance
# city number 295: city name seydi
# city number 296: city name komsomolskiy
# city number 297: city name ulaangom
# city number 298: city name iranshahr
# city number 299: city name ust-nera
# city number 300: city name lerwick
# city number 301: city name mont-dore
# city number 302: city name haverfordwest
# city number 303: city name tuatapere
# Oops, that key doesn't exist.
# city number 304: city name sanguem
# Oops, that key doesn't exist.
# city number 305: city name boyuibe
# Oops, that key doesn't exist.
# city number 306: city name hamilton
# city number 307: city name vila franca do campo
# city number 308: city name constitucion
# city number 309: city name vila velha
# city number 310: city name astana
# Oops, that key doesn't exist.
# city number 311: city name suhbaatar
# city number 312: city name khabary
# city number 313: city name jalu
# city number 314: city name mackay
# city number 315: city name nioro
# city number 316: city name raudeberg
# city number 317: city name ariquemes
# Oops, that key doesn't exist.
# city number 318: city name talnakh
# city number 319: city name perene
# city number 320: city name cruz grande
# city number 321: city name pacific grove
# city number 322: city name green river
# city number 323: city name sola
# city number 324: city name badvel
# city number 325: city name tuy hoa
# city number 326: city name tabuk
# city number 327: city name lukulu
# city number 328: city name walvis bay
# city number 329: city name kieta
# city number 330: city name havelock
# city number 331: city name mareeba
# city number 332: city name kushima
# city number 333: city name kilindoni
# Oops, that key doesn't exist.
# city number 334: city name alta floresta
# city number 335: city name sunbury
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# city number 336: city name nanortalik
# city number 337: city name barcelos
# city number 338: city name tara
# city number 339: city name simao
# city number 340: city name sao jose da coroa grande
# Oops, that key doesn't exist.
# Oops, that key doesn't exist.
# city number 341: city name cairns
# city number 342: city name storm lake
# city number 343: city name kirovskiy
# city number 344: city name nizhnyaya poyma
# city number 345: city name beloha
# city number 346: city name nsukka
# city number 347: city name viedma
# city number 348: city name olinda
# city number 349: city name san alejo
# city number 350: city name kalmunai
# city number 351: city name vilhena
# city number 352: city name pisco
# city number 353: city name torbay
# city number 354: city name nueva imperial
# city number 355: city name itoman
# city number 356: city name aksu
# Oops, that key doesn't exist.
# city number 357: city name yuncheng
# city number 358: city name lokachi
# city number 359: city name prince albert
# city number 360: city name harper
# city number 361: city name asosa
# city number 362: city name zaraza
# city number 363: city name ponta delgada
# city number 364: city name mushie
# city number 365: city name bull savanna
# city number 366: city name beringovskiy
# city number 367: city name salekhard
# city number 368: city name novoorsk
# city number 369: city name mehamn
# city number 370: city name college
# city number 371: city name ulladulla
# city number 372: city name biak
# city number 373: city name puerto colombia
# city number 374: city name cayenne
# city number 375: city name bambanglipuro
# Oops, that key doesn't exist.
# city number 376: city name agucadoura
# city number 377: city name ust-kuyga
# city number 378: city name marondera
# city number 379: city name half moon bay
# city number 380: city name lorengau
# city number 381: city name georgiyevskoye
# city number 382: city name novyy svit
# city number 383: city name rybachiy
# Oops, that key doesn't exist.
# city number 384: city name mitha tiwana
# city number 385: city name san carlos
# city number 386: city name amazar
# city number 387: city name hirara
# city number 388: city name gerede
# city number 389: city name kikwit
# city number 390: city name rawson
# city number 391: city name parabel
# city number 392: city name sawakin
# city number 393: city name niltepec
# city number 394: city name abeche
# city number 395: city name senador jose porfirio
# city number 396: city name sligo
# city number 397: city name aras
# city number 398: city name uglekamensk
# city number 399: city name inhambane
# city number 400: city name alice springs
# city number 401: city name impfondo
# city number 402: city name okato
# city number 403: city name tabou
# city number 404: city name sur
# city number 405: city name te anau
# city number 406: city name roma
# city number 407: city name trairi
# Oops, that key doesn't exist.
# city number 408: city name inongo
# city number 409: city name havre-saint-pierre
# Oops, that key doesn't exist.
# city number 410: city name yarim
# city number 411: city name charters towers
# Oops, that key doesn't exist.
# city number 412: city name manta
# city number 413: city name huilong
# city number 414: city name ostersund
# city number 415: city name shimoda
# Oops, that key doesn't exist.
# city number 416: city name laurel
# Oops, that key doesn't exist.
# city number 417: city name albemarle
# Oops, that key doesn't exist.
# city number 418: city name boa vista
# city number 419: city name dunedin
# city number 420: city name mundo nuevo
# city number 421: city name tabora
# Oops, that key doesn't exist.
# city number 422: city name vestmannaeyjar
# city number 423: city name grants pass
# city number 424: city name tomatlan
# city number 425: city name faya
# city number 426: city name chuy
# city number 427: city name monki
# city number 428: city name lufilufi
# city number 429: city name canguaretama
# city number 430: city name saint-louis
# city number 431: city name sosnovoborsk
# city number 432: city name irbeyskoye
# Oops, that key doesn't exist.
# city number 433: city name beisfjord
# city number 434: city name hanyang
# city number 435: city name arlit
# city number 436: city name grigoropolisskaya
# city number 437: city name isangel
# city number 438: city name turbat
# city number 439: city name tres picos
# city number 440: city name neya
# city number 441: city name gunjur
# city number 442: city name evensk
# city number 443: city name nebbi
# city number 444: city name ahipara
# Oops, that key doesn't exist.
# city number 445: city name zhoucheng
# city number 446: city name aykhal
# city number 447: city name paracuru
# city number 448: city name ternate
# city number 449: city name anadyr
# city number 450: city name tautira
# Oops, that key doesn't exist.
# city number 451: city name bilibino
# city number 452: city name burns lake
# city number 453: city name fort frances
# city number 454: city name nelson bay
# city number 455: city name altamira
# city number 456: city name mahina
# city number 457: city name namatanai
# city number 458: city name nizhniy baskunchak
# city number 459: city name salalah
# city number 460: city name nobeoka
# city number 461: city name manacapuru
# Oops, that key doesn't exist.
# city number 462: city name kearney
# city number 463: city name yaroslavl
# city number 464: city name palana
# city number 465: city name kharitonovo
# city number 466: city name noshiro
# city number 467: city name bonfim
# city number 468: city name benidorm
# city number 469: city name turtas
# city number 470: city name vikulovo
# city number 471: city name amboasary
# city number 472: city name iguatemi
# Oops, that key doesn't exist.
# city number 473: city name najran
# city number 474: city name grindavik
# city number 475: city name pau
# city number 476: city name prabumulih
# city number 477: city name mandalgovi
# city number 478: city name union
# city number 479: city name akdepe
# city number 480: city name conde
# city number 481: city name antofagasta
# city number 482: city name jacqueville
# city number 483: city name kahului
# city number 484: city name miranda
# Oops, that key doesn't exist.
# city number 485: city name luganville
# city number 486: city name boca del monte
# city number 487: city name kabelvag
# city number 488: city name tiangua
# city number 489: city name sasvad
# city number 490: city name sistranda
# city number 491: city name oriximina
# city number 492: city name shaunavon
# city number 493: city name sarahan
# city number 494: city name manzil salim
# city number 495: city name clyde river
# city number 496: city name mapastepec
# city number 497: city name zhezkazgan
# city number 498: city name mana
# city number 499: city name oktyabrskiy
# city number 500: city name ullapool
# Oops, that key doesn't exist.
# city number 501: city name xining
# city number 502: city name soyo
# city number 503: city name lakatoro
# city number 504: city name camocim
# city number 505: city name tucumcari
# Oops, that key doesn't exist.
# city number 506: city name kirksville
# city number 507: city name eureka
# Oops, that key doesn't exist.
# city number 508: city name manuk mangkaw
# city number 509: city name kampot
# city number 510: city name high rock
# city number 511: city name sorong
# city number 512: city name flin flon
# city number 513: city name havoysund
# Oops, that key doesn't exist.
# city number 514: city name naze
# city number 515: city name warangal
# city number 516: city name mazamet
# city number 517: city name buchanan
# city number 518: city name leshukonskoye
# city number 519: city name kupang
# city number 520: city name pasighat
# city number 521: city name chaoyang
# city number 522: city name bachaquero
# city number 523: city name madinat sittah uktubar
# city number 524: city name manaulanan
# city number 525: city name havelian
# city number 526: city name perth
# city number 527: city name bar
# city number 528: city name abu kamal
# city number 529: city name chicama
# city number 530: city name kedrovyy
# city number 531: city name brownsville
# city number 532: city name sault sainte marie
# city number 533: city name khani
# city number 534: city name kimbe
# Oops, that key doesn't exist.
# city number 535: city name tura
# city number 536: city name paamiut
# city number 537: city name belaya gora
# city number 538: city name pedasi
# city number 539: city name healesville
# city number 540: city name kutum
# city number 541: city name susanville
# city number 542: city name ilulissat
# city number 543: city name steinbach
# city number 544: city name margate
# city number 545: city name nadvoitsy
# city number 546: city name acajutla
# city number 547: city name winnemucca
# city number 548: city name salinopolis

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data=pd.DataFrame({"City":city_new, "Cloudiness":cloudiness,"Country":country_new,"Humidity":humidity,"Lat":lat,"Lng":lng, "Max Temp":temp,"Wind Speed":wind_speed})
data.head()
# Out:
#                 City  Cloudiness Country  Humidity    Lat     Lng  Max Temp  \
# 0            mataura           0      pf        94 -46.19  168.86     54.00
# 1             bethel          20      us        92  60.79 -161.76     28.40
# 2         port blair          24      in       100  11.67   92.75     84.27
# 3  sao joao da barra          75      br        61 -21.64  -41.05     80.60
# 4          cape town          20      za        88 -33.93   18.42     70.00
#
#    Wind Speed
# 0        2.95
# 1        3.36
# 2        5.75
# 3        5.82
# 4       12.75

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data["Lat"],data["Max Temp"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Max Temparature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("LatvsTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data["Lat"],data["Humidity"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.savefig("LatvsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data["Lat"],data["Cloudiness"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.savefig("LatvsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data["Lat"],data["Wind Speed"],c="lightblue",marker="o",edgecolors="black")
plt.grid(b=None, which='major', axis='both')
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("LatvsWind.png")
